# %%
import pandas as pd
df = pd.read_csv("data/accidentsVelofull.csv")
# Out:
# C:\Users\anael\AppData\Local\Temp\ipykernel_62252\2971648107.py:2: DtypeWarning: Columns (17,30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("data/accidentsVelofull.csv")

# %%
df.head()
# Out:
#         Num_Acc        date    an     mois      jour   hrmn dep    com  \
# 0  200500000030  2005-01-13  2005  janvier     jeudi  19:45  62  62331
# 1  200500000034  2005-01-19  2005  janvier  mercredi  10:45  62  62022
# 2  200500000078  2005-01-26  2005  janvier  mercredi  13:15  02  02173
# 3  200500000093  2005-01-03  2005  janvier     lundi  13:30  02  02810
# 4  200500000170  2005-01-29  2005  janvier    samedi  18:30  76  76196
#
#       lat   long  ...  equipement  obs  obsm  choc  manv       vehiculeid  \
# 0  50.300  2.840  ...           0  0.0   2.0   8.0  11.0  200500000030B02
# 1   0.000  0.000  ...           0  0.0   2.0   1.0   1.0  200500000034B02
# 2   0.000  0.000  ...           2  0.0   2.0   1.0   1.0  200500000078B02
# 3  49.255  3.094  ...           0  0.0   2.0   3.0  21.0  200500000093B02
# 4   0.000  0.000  ...           9  0.0   2.0   4.0   2.0  200500000170A01
#
#    typevehicules manoeuvehicules  numVehicules  _infos_commune.code_epci
# ...

# %%
df[df["grav"] == 2]
# Out:
#             Num_Acc        date    an       mois      jour   hrmn  dep    com  \
# 14     200500000329  2005-01-04  2005    janvier     mardi  19:00   50  50213
# 19     200500000438  2005-01-24  2005    janvier     lundi  12:15   72  72154
# 23     200500000553  2005-01-09  2005    janvier  dimanche  18:00   47  47305
# 33     200500000874  2005-01-10  2005    janvier     lundi  17:00   38  38545
# 43     200500001174  2005-01-04  2005    janvier     mardi  15:45   51  51024
# ...             ...         ...   ...        ...       ...    ...  ...    ...
# 79970  202300053487  2023-08-18  2023       août  vendredi  15:35   77  77327
# 79994  202300054107  2023-09-27  2023  septembre  mercredi  14:55   25  25524
# 80001  202300054301  2023-03-28  2023       mars     mardi  14:00  974  97404
# 80010  202300054564  2023-07-15  2023    juillet    samedi  08:40   73  73303
# 80016  202300054623  2023-02-13  2023    février     lundi  09:00   38  38317
#
# ...

# %%
df_grav4 = df[df["grav"] == 4]
len(df_grav4["Num_Acc"].unique())
# Out:
# 44591

# %%
df["typevehicules"].value_counts()
# Out:
# typevehicules
# 7              51010
# 10              4763
# 1               2935
# 33              1330
# 2               1137
#                ...
# 30 / 34 / 7        1
# 3 / 14             1
# 15 / 33 / 7        1
# 10 / 15            1
# 33 / 17            1
# Name: count, Length: 136, dtype: int64

# %%
df["typevehicules"].value_counts()
# Out:
# typevehicules
# 7              51010
# 10              4763
# 1               2935
# 33              1330
# 2               1137
#                ...
# 30 / 34 / 7        1
# 3 / 14             1
# 15 / 33 / 7        1
# 10 / 15            1
# 33 / 17            1
# Name: count, Length: 136, dtype: int64
